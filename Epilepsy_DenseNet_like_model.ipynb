# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv('Epileptic Seizure Recognition.csv')
data.head()
# Out:
#       Unnamed   X1   X2   X3   X4   X5   X6   X7   X8   X9  ...  X170  X171  \
# 0  X21.V1.791  135  190  229  223  192  125   55   -9  -33  ...   -17   -15
# 1  X15.V1.924  386  382  356  331  320  315  307  272  244  ...   164   150
# 2     X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  ...    57    64
# 3   X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  ...   -82   -81
# 4   X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  ...     4     2
#
#    X172  X173  X174  X175  X176  X177  X178  y
# 0   -31   -77  -103  -127  -116   -83   -51  4
# 1   146   152   157   156   154   143   129  1
# 2    48    19   -12   -30   -35   -35   -36  5
# 3   -80   -77   -85   -77   -72   -69   -65  5
# 4   -12   -32   -41   -65   -83   -89   -73  5
#
# [5 rows x 180 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11500 entries, 0 to 11499
# Columns: 180 entries, Unnamed to y
# dtypes: int64(179), object(1)
# memory usage: 15.8+ MB

# %%
X = data.iloc[:,1:-1].values
X.shape
# Out:
# (11500, 178)

# %%
y = data.iloc[:,-1:].values
y[y>1] = 0
y.shape
# Out:
# (11500, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20,shuffle=True)
X_train.shape,y_test.shape
# Out:
# ((9200, 178), (2300, 1))

# %%
def denseBlock(dims,inp) :
    x = tf.keras.layers.BatchNormalization() (inp)
    x = tf.keras.layers.Dense(dims,activation=tf.keras.layers.LeakyReLU(0.2)) (x)
    x = tf.keras.layers.Dropout(0.4) (x)
    x = tf.keras.layers.Dense(dims,activation=tf.keras.layers.LeakyReLU(0.2)) (x)
    x = tf.keras.layers.Dropout(0.4) (x)
    x = tf.keras.layers.Dense(dims,activation=tf.keras.layers.LeakyReLU(0.2)) (x)
    x = tf.keras.layers.Dropout(0.4) (x)
    x = tf.keras.layers.Dense(178,activation=tf.keras.layers.LeakyReLU(0.2)) (x)
    return x

# %%
inp = tf.keras.layers.Input(shape=(178,),name='input')
x1 = denseBlock(256,inp)
x2 = denseBlock(512,inp)
x3 = denseBlock(1024,inp)
x = tf.keras.layers.Concatenate()([x1,x2,x3])
x = tf.keras.layers.Dense(128,activation=tf.keras.layers.LeakyReLU(0.2)) (x)
out = tf.keras.layers.Dense(1,activation='sigmoid',name='output') (x)

model = tf.keras.models.Model(inp,out)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 178)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 178)       │        712 │ input[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 178)       │        712 │ input[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 178)       │        712 │ input[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │     45,824 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 512)       │     91,648 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 1024)      │    183,296 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 512)       │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 1024)      │          0 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │     65,792 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 512)       │    262,656 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 1024)      │  1,049,600 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 256)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 512)       │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 1024)      │          0 │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 256)       │     65,792 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 512)       │    262,656 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 1024)      │  1,049,600 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 256)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 512)       │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 1024)      │          0 │ dense_10[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 178)       │     45,746 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 178)       │     91,314 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 178)       │    182,450 │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 534)       │          0 │ dense_3[0][0],    │
# │ (Concatenate)       │                   │            │ dense_7[0][0],    │
# │                     │                   │            │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 128)       │     68,480 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 1)         │        129 │ dense_12[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,467,119 (13.23 MB)
#  Trainable params: 3,466,051 (13.22 MB)
#  Non-trainable params: 1,068 (4.17 KB)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train_scaled = sc.fit_transform(X_train)
x_test_scaled = sc.transform(X_test)
model.compile(loss='binary_crossentropy',optimizer=tf.keras.optimizers.Adam(1e-4),metrics=['accuracy'])
model.fit(X_train,y_train,epochs=150,batch_size=128,validation_split=0.2)
# Out:
# Epoch 1/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 30s 206ms/step - accuracy: 0.6205 - loss: 0.6766 - val_accuracy: 0.9103 - val_loss: 0.4529
# Epoch 2/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 21s 201ms/step - accuracy: 0.8990 - loss: 0.4506 - val_accuracy: 0.9440 - val_loss: 0.2565
# Epoch 3/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 21s 194ms/step - accuracy: 0.9375 - loss: 0.2369 - val_accuracy: 0.9636 - val_loss: 0.1601
# Epoch 4/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 110ms/step - accuracy: 0.9471 - loss: 0.1761 - val_accuracy: 0.9571 - val_loss: 0.1871
# Epoch 5/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 13s 143ms/step - accuracy: 0.9525 - loss: 0.1522 - val_accuracy: 0.9652 - val_loss: 0.1267
# Epoch 6/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.9637 - loss: 0.1200 - val_accuracy: 0.9658 - val_loss: 0.1087
# Epoch 7/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 128ms/step - accuracy: 0.9668 - loss: 0.1116 - val_accuracy: 0.9658 - val_loss: 0.1340
# Epoch 8/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - accuracy: 0.9688 - loss: 0.1034 - val_accuracy: 0.9679 - val_loss: 0.1070
# Epoch 9/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - accuracy: 0.9711 - loss: 0.0903 - val_accuracy: 0.9674 - val_loss: 0.1095
# Epoch 10/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - accuracy: 0.9735 - loss: 0.0852 - val_accuracy: 0.9690 - val_loss: 0.0957
# Epoch 11/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 15s 191ms/step - accuracy: 0.9704 - loss: 0.0918 - val_accuracy: 0.9668 - val_loss: 0.1129
# Epoch 12/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9744 - loss: 0.0776 - val_accuracy: 0.9707 - val_loss: 0.1035
# Epoch 13/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 105ms/step - accuracy: 0.9760 - loss: 0.0783 - val_accuracy: 0.9701 - val_loss: 0.0978
# Epoch 14/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.9772 - loss: 0.0685 - val_accuracy: 0.9658 - val_loss: 0.1090
# Epoch 15/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 16s 208ms/step - accuracy: 0.9773 - loss: 0.0637 - val_accuracy: 0.9728 - val_loss: 0.0942
# Epoch 16/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - accuracy: 0.9787 - loss: 0.0677 - val_accuracy: 0.9685 - val_loss: 0.0999
# Epoch 17/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 180ms/step - accuracy: 0.9801 - loss: 0.0607 - val_accuracy: 0.9707 - val_loss: 0.1026
# Epoch 18/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 14s 243ms/step - accuracy: 0.9807 - loss: 0.0601 - val_accuracy: 0.9712 - val_loss: 0.0981
# Epoch 19/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 187ms/step - accuracy: 0.9756 - loss: 0.0718 - val_accuracy: 0.9679 - val_loss: 0.1093
# Epoch 20/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 13s 218ms/step - accuracy: 0.9821 - loss: 0.0531 - val_accuracy: 0.9679 - val_loss: 0.1099
# Epoch 21/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 22s 224ms/step - accuracy: 0.9818 - loss: 0.0586 - val_accuracy: 0.9723 - val_loss: 0.0952
# Epoch 22/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 289ms/step - accuracy: 0.9827 - loss: 0.0499 - val_accuracy: 0.9696 - val_loss: 0.1106
# Epoch 23/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.9796 - loss: 0.0597 - val_accuracy: 0.9690 - val_loss: 0.1093
# Epoch 24/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 191ms/step - accuracy: 0.9813 - loss: 0.0556 - val_accuracy: 0.9712 - val_loss: 0.0969
# Epoch 25/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 22s 210ms/step - accuracy: 0.9846 - loss: 0.0524 - val_accuracy: 0.9728 - val_loss: 0.0930
# Epoch 26/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 203ms/step - accuracy: 0.9810 - loss: 0.0505 - val_accuracy: 0.9723 - val_loss: 0.1055
# Epoch 27/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 290ms/step - accuracy: 0.9820 - loss: 0.0504 - val_accuracy: 0.9723 - val_loss: 0.0943
# Epoch 28/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 24s 392ms/step - accuracy: 0.9834 - loss: 0.0462 - val_accuracy: 0.9712 - val_loss: 0.1151
# Epoch 29/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 12s 209ms/step - accuracy: 0.9823 - loss: 0.0475 - val_accuracy: 0.9717 - val_loss: 0.1010
# Epoch 30/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 125ms/step - accuracy: 0.9839 - loss: 0.0450 - val_accuracy: 0.9707 - val_loss: 0.1202
# Epoch 31/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 106ms/step - accuracy: 0.9849 - loss: 0.0466 - val_accuracy: 0.9739 - val_loss: 0.0973
# Epoch 32/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.9859 - loss: 0.0429 - val_accuracy: 0.9734 - val_loss: 0.0990
# Epoch 33/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 159ms/step - accuracy: 0.9839 - loss: 0.0455 - val_accuracy: 0.9728 - val_loss: 0.1053
# Epoch 34/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 182ms/step - accuracy: 0.9876 - loss: 0.0336 - val_accuracy: 0.9707 - val_loss: 0.1206
# Epoch 35/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9828 - loss: 0.0486 - val_accuracy: 0.9717 - val_loss: 0.1211
# Epoch 36/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - accuracy: 0.9840 - loss: 0.0478 - val_accuracy: 0.9712 - val_loss: 0.1085
# Epoch 37/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.9861 - loss: 0.0403 - val_accuracy: 0.9728 - val_loss: 0.0939
# Epoch 38/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 14s 181ms/step - accuracy: 0.9879 - loss: 0.0363 - val_accuracy: 0.9685 - val_loss: 0.1291
# Epoch 39/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.9880 - loss: 0.0346 - val_accuracy: 0.9723 - val_loss: 0.1072
# Epoch 40/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 163ms/step - accuracy: 0.9852 - loss: 0.0457 - val_accuracy: 0.9717 - val_loss: 0.1151
# Epoch 41/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 119ms/step - accuracy: 0.9851 - loss: 0.0405 - val_accuracy: 0.9685 - val_loss: 0.1289
# Epoch 42/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 147ms/step - accuracy: 0.9861 - loss: 0.0387 - val_accuracy: 0.9739 - val_loss: 0.1026
# Epoch 43/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 13s 191ms/step - accuracy: 0.9868 - loss: 0.0423 - val_accuracy: 0.9679 - val_loss: 0.1254
# Epoch 44/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 162ms/step - accuracy: 0.9857 - loss: 0.0444 - val_accuracy: 0.9658 - val_loss: 0.1364
# Epoch 45/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 12s 184ms/step - accuracy: 0.9875 - loss: 0.0380 - val_accuracy: 0.9734 - val_loss: 0.1063
# Epoch 46/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 12s 198ms/step - accuracy: 0.9886 - loss: 0.0296 - val_accuracy: 0.9723 - val_loss: 0.1183
# Epoch 47/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.9878 - loss: 0.0350 - val_accuracy: 0.9701 - val_loss: 0.1140
# Epoch 48/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 12s 202ms/step - accuracy: 0.9876 - loss: 0.0364 - val_accuracy: 0.9717 - val_loss: 0.1216
# Epoch 49/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 156ms/step - accuracy: 0.9862 - loss: 0.0387 - val_accuracy: 0.9696 - val_loss: 0.1197
# Epoch 50/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 12s 178ms/step - accuracy: 0.9882 - loss: 0.0324 - val_accuracy: 0.9739 - val_loss: 0.0944
# Epoch 51/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 178ms/step - accuracy: 0.9888 - loss: 0.0316 - val_accuracy: 0.9690 - val_loss: 0.1321
# Epoch 52/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 12s 207ms/step - accuracy: 0.9916 - loss: 0.0289 - val_accuracy: 0.9707 - val_loss: 0.1283
# Epoch 53/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 21s 203ms/step - accuracy: 0.9874 - loss: 0.0317 - val_accuracy: 0.9712 - val_loss: 0.1156
# Epoch 54/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 21s 207ms/step - accuracy: 0.9918 - loss: 0.0259 - val_accuracy: 0.9707 - val_loss: 0.1221
# Epoch 55/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 21s 199ms/step - accuracy: 0.9876 - loss: 0.0326 - val_accuracy: 0.9745 - val_loss: 0.0945
# Epoch 56/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 16s 116ms/step - accuracy: 0.9882 - loss: 0.0308 - val_accuracy: 0.9674 - val_loss: 0.1367
# Epoch 57/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 258ms/step - accuracy: 0.9895 - loss: 0.0305 - val_accuracy: 0.9690 - val_loss: 0.1206
# Epoch 58/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━
150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.9963 - loss: 0.0128 - val_accuracy: 0.9723 - val_loss: 0.1224
# Epoch 118/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 167ms/step - accuracy: 0.9956 - loss: 0.0123 - val_accuracy: 0.9723 - val_loss: 0.1531
# Epoch 119/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 185ms/step - accuracy: 0.9935 - loss: 0.0169 - val_accuracy: 0.9712 - val_loss: 0.1483
# Epoch 120/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 180ms/step - accuracy: 0.9948 - loss: 0.0148 - val_accuracy: 0.9739 - val_loss: 0.1399
# Epoch 121/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.9953 - loss: 0.0139 - val_accuracy: 0.9701 - val_loss: 0.1419
# Epoch 122/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 13s 216ms/step - accuracy: 0.9960 - loss: 0.0105 - val_accuracy: 0.9728 - val_loss: 0.1392
# Epoch 132/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 13s 231ms/step - accuracy: 0.9964 - loss: 0.0097 - val_accuracy: 0.9712 - val_loss: 0.1576
# Epoch 133/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 12s 200ms/step - accuracy: 0.9980 - loss: 0.0081 - val_accuracy: 0.9750 - val_loss: 0.1561
# Epoch 134/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 13s 229ms/step - accuracy: 0.9957 - loss: 0.0120 - val_accuracy: 0.9739 - val_loss: 0.1473
# Epoch 135/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 21s 220ms/step - accuracy: 0.9956 - loss: 0.0137 - val_accuracy: 0.9707 - val_loss: 0.1545
# Epoch 136/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 173ms/step - accuracy: 0.9969 - loss: 0.0116 - val_accuracy: 0.9723 - val_loss: 0.1399
# Epoch 137/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 12s 188ms/step - accuracy: 0.9958 - loss: 0.0139 - val_accuracy: 0.9707 - val_loss: 0.1658
# Epoch 138/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - accuracy: 0.9918 - loss: 0.0227 - val_accuracy: 0.9723 - val_loss: 0.1526
# Epoch 139/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 21s 183ms/step - accuracy: 0.9935 - loss: 0.0171 - val_accuracy: 0.9685 - val_loss: 0.1435
# Epoch 140/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.9949 - loss: 0.0142 - val_accuracy: 0.9690 - val_loss: 0.1435
# Epoch 141/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 19s 165ms/step - accuracy: 0.9962 - loss: 0.0109 - val_accuracy: 0.9739 - val_loss: 0.1246
# Epoch 142/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 166ms/step - accuracy: 0.9957 - loss: 0.0146 - val_accuracy: 0.9761 - val_loss: 0.1043
# Epoch 143/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 167ms/step - accuracy: 0.9910 - loss: 0.0249 - val_accuracy: 0.9696 - val_loss: 0.1576
# Epoch 144/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 168ms/step - accuracy: 0.9956 - loss: 0.0161 - val_accuracy: 0.9734 - val_loss: 0.1385
# Epoch 145/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 168ms/step - accuracy: 0.9969 - loss: 0.0095 - val_accuracy: 0.9717 - val_loss: 0.1409
# Epoch 146/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 169ms/step - accuracy: 0.9965 - loss: 0.0125 - val_accuracy: 0.9685 - val_loss: 0.1754
# Epoch 147/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.9943 - loss: 0.0162 - val_accuracy: 0.9717 - val_loss: 0.1425
# Epoch 148/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 169ms/step - accuracy: 0.9949 - loss: 0.0138 - val_accuracy: 0.9723 - val_loss: 0.1497
# Epoch 149/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 165ms/step - accuracy: 0.9975 - loss: 0.0065 - val_accuracy: 0.9717 - val_loss: 0.1666
# Epoch 150/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - accuracy: 0.9959 - loss: 0.0118 - val_accuracy: 0.9723 - val_loss: 0.1454

# %%
model.evaluate(X_test,y_test)
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9686 - loss: 0.1584
# [0.15787972509860992, 0.9700000286102295]

# %%
loss, accuracy = model.evaluate(X_test, y_test)

print("Loss:", loss)
print("Accuracy:", accuracy * 100, "%")
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9686 - loss: 0.1584
# Loss: 0.15787972509860992
# Accuracy: 97.00000286102295 %
